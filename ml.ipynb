# %% [markdown]
# <a href="https://colab.research.google.com/github/3aswarconnect/30-days-challenge/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('apple_quality(class).csv')
df
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...    ...       ...       ...        ...          ...        ...       ...
# 3648  3648 -0.721063 -0.848216  -0.706661     0.802176  -0.381320 -0.545140
# 3649  3649  1.833620 -4.414765   0.962195     4.172800   1.154648  2.276095
# 3650  3650 -3.947005  3.164370  -2.037452     0.765064   2.937938 -1.403866
# 3651  3651  2.539110 -1.781324  -0.464490     2.843897   4.002744 -2.228520
# 3652  3652 -3.245999  2.514563   0.259883    -1.334723   1.824931 -1.338920
#
#        Acidity Quality
# 0    -0.491590    good
# ...

# %%
df.isnull().sum()
# df['Size'].fillna(df['Size'].mean(),inplace=True)
# df
# Out:
# A_id           0
# Size           0
# Weight         6
# Sweetness      2
# Crunchiness    4
# Juiciness      5
# Ripeness       2
# Acidity        0
# Quality        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your data is stored in a DataFrame called df
quality_encoder = LabelEncoder()
df['Quality'] = quality_encoder.fit_transform(df['Quality'])
df
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...    ...       ...       ...        ...          ...        ...       ...
# 3648  3648 -0.721063 -0.848216  -0.706661     0.802176  -0.381320 -0.545140
# 3649  3649  1.833620 -4.414765   0.962195     4.172800   1.154648  2.276095
# 3650  3650 -3.947005  3.164370  -2.037452     0.765064   2.937938 -1.403866
# 3651  3651  2.539110 -1.781324  -0.464490     2.843897   4.002744 -2.228520
# 3652  3652 -3.245999  2.514563   0.259883    -1.334723   1.824931 -1.338920
#
#        Acidity  Quality
# 0    -0.491590        1
# ...
